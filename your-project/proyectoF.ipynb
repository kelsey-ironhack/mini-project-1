# %%
import random
import string
import re
print('==================================================================')
print("""Hola a continuacion este programa le generara una 
contraseña para poder crear su cuenta en la plataforma\n""")

usuario=input("Primero introduzca su nombre de usuario: ")
ans=True
while ans:
    print ("""
    1.Contrasena por default (9 caracteres)
    2.Elegir la longitud de mi contrasena
    3.Salir
    """)
    ans=input("Elija una opcion del menu anterior: ")
    if ans=="1":
        def shuffle(string):
            tempList = list(string)
            random.shuffle(tempList)
            return ''.join(tempList)
        lmy1=chr(random.randint(65,90)) 
        lmy2=chr(random.randint(65,90)) 
        lmc1=chr(random.randint(97,122)) 
        lmc2=chr(random.randint(97,122)) 
        lmc3=chr(random.randint(97,122)) 
        lmc4=chr(random.randint(97,122)) 
        n1=chr(random.randint(48,57)) 
        n2=chr(random.randint(48,57)) 
        se1=chr(random.randint(33,47))

        password = lmy1 + lmy2 + lmc1+lmc2+lmc3+lmc4+n1+n2+se1
        password = shuffle(password)
        print(f'Su contraseña es: {password}')
    
    if ans=="2":
        i=int(input("Escriba la longitud deseada para su contraseña: "))
        def pass_random(i):
            
            return ''.join(random.choice(string.ascii_letters+string.digits+string.punctuation) for x in range(i))
        password=(pass_random(i))
        print(f'Su contrasena es: {password}')
    
    if ans=="3":
        print("Gracias vuelva pronto")
    break
   
print("Ingrese nuevamente usuario y contraseña para la creacion de su cuenta\n")

us1=input("Confirme su usuario: ")

while us1!=usuario:
    print('Usuario incorrecto, vuelva a intentarlo')
    us1=input("Confirme su usuario: ")
pass
pass2=input("Confirme contraseña: ")
while pass2!=password:
    print('Contraseña incorrecta, vuelva a intentarlo')
    pass2=input("Confirme contraseña: ")
pass
correo=input("Proporcione un correo para mandarle los detalles de su cuenta: ")
re.findall(r'@[a-z]+.com',correo)
while re.findall(r'@[a-z]+.com',correo):
    print("Gracias se enviaron sus datos")
    break
else:
    print("Correo incorrecto, vuelva a intentarlo")
    correo=input("Proporcione un correo para mandarle los detalles de su cuenta: ")
    print('Gracias, sus datos se han enviado correctamente')
# Out:
# ...
# Hola a continuacion este programa le generara una
# contraseña para poder crear su cuenta en la plataforma
#
# Primero introduzca su nombre de usuario: jesus
#
#     1.Contrasena por default (9 caracteres)
#     2.Elegir la longitud de mi contrasena
#     3.Salir
#
# Elija una opcion del menu anterior: 2
# Escriba la longitud deseada para su contraseña: 4
# Su contrasena es: #QL2
# Ingrese nuevamente usuario y contraseña para la creacion de su cuenta
#
# Confirme su usuario: jessd
# vuelva a intentarlo
# Confirme su usuario: jesus
# Confirme contraseña: sdfsd
# vuelva a intentarlo
# Confirme contraseña: #QL2
# Proporcione un correo para mandarle los detalles de su cuenta: jesrs.com
# Correo incorrecto, vuelva a intentarlo
# Proporcione un correo para mandarle los detalles de su cuenta: jesus@gmail.com
# Gracias, sus datos se han enviado correctamente
