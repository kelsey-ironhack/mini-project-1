# %%
import random

cartas1 = {'As corazon': 1, '2 corazon': 2, '3 corazon': 3, "4 corazon": 4, '5 corazon': 5, '6 corazon': 6, '7 corazon': 7, 
           '8 corazon': 8, '9 corazon': 9, '10 corazon': 10, 'Joto corazon': 10, 'Quina Corazon': 10, 'Rey Corazon': 10,
           'As Diamante': 1, '2 Diamante': 2, '3 Diamante': 3, "4 Diamante": 4, '5 Diamante': 5, '6 Diamante': 6, 
           '7 Diamante': 7, '8 Diamante': 8, '9 Diamante': 9, '10 Diamante': 10, 'Joto Diamante': 10, 'Quina Diamante': 10, 
           'Rey Diamante': 10, 'As Espada': 1, '2 Espada': 2, '3 Espada': 3, "4 Espada": 4, '5 Espada': 5, '6 Espada': 6, 
           '7 Espada': 7, '8 Espada': 8, '9 Espada': 9, '10 Espada': 10, 'Joto Espada': 10, 'Quina Espada': 10, 
           'Rey Espada': 10, 'As Trebol': 1, '2 Trebol': 2, '3 Trebol': 3, "4 Trebol": 4, '5 Trebol': 5, '6 Trebol': 6, 
           '7 Trebol': 7, '8 Trebol': 8, '9 Trebol': 9, '10 Trebol': 10, 'Joto Trebol': 10, 'Quina Trebol': 10, 
           'Rey Trebol': 10}

cartas2 = {'As corazon2': 1, '2 corazon2': 2, '3 corazon2': 3, "4 corazon2": 4, '5 corazon2': 5, '6 corazon2': 6, 
           '7 corazon2': 7, '8 corazon2': 8, '9 corazon2': 9, '10 corazon2': 10, 'Joto corazon2': 10, 'Quina Corazon2': 10, 
           'Rey Corazon2': 10, 'As Diamante2': 1, "2 Diamante2": 2, "3 Diamante2": 3, "4 Diamante2": 4, "5 Diamante2": 5,
           '6 Diamante2': 6, '7 Diamante2': 7, '8 Diamante2': 8, '9 Diamante2': 9, '10 Diamante2': 10, 'Joto Diamante2': 10, 
           'Quina Diamante2': 10, 'Rey Diamante2': 10, 'As Espada2': 1, '2 Espada2': 2, '3 Espada2': 3, "4 Espada2": 4, 
           '5 Espada2': 5, '6 Espada2': 6, '7 Espada2': 7, '8 Espada2': 8, '9 Espada2': 9, '10 Espada2': 10, 'Joto Espada2': 10, 
           'Quina Espada2': 10, 'Rey Espada2': 10,'As Trebol2': 1, '2 Trebol2': 2, '3 Trebol2': 3, "4 Trebol2": 4, 
           '5 Trebol2': 5,'6 Trebol2': 6, '7 Trebol2': 7, '8 Trebol2': 8, '9 Trebol2': 9, '10 Trebol2': 10, 'Joto Trebol2': 10,
           'Quina Trebol2': 10, 'Rey Trebol2': 10}

cartas3 = {'As corazon3': 1, '2 corazon3': 2, '3 corazon3': 3, "4 corazon3": 4, '5 corazon3': 5, '6 corazon3': 6, 
           '7 corazon3': 7, '8 corazon3': 8, '9 corazon3': 9, '10 corazon3': 10, 'Joto corazo3': 10, 'Quina Corazon3': 10, 
           'Rey Corazon3': 10, 'As Diamante3': 1, "2 Diamante3": 2, "3 Diamante3": 3, "4 Diamante3": 4, "5 Diamante3": 5,
           '6 Diamante3': 6, '7 Diamante3': 7, '8 Diamante3': 8, '9 Diamante3': 9, '10 Diamante3': 10, 'Joto Diamante3': 10, 
           'Quina Diamante3': 10, 'Rey Diamante3': 10, 'As Espada3': 1, '2 Espada3': 2, '3 Espada3': 3, "4 Espada3": 4, 
           '5 Espada3': 5, '6 Espada3': 6, '7 Espada3': 7, '8 Espada3': 8, '9 Espada3': 9, '10 Espada3': 10, 'Joto Espada3': 10, 
           'Quina Espada3': 10, 'Rey Espada3': 10,'As Trebol3': 1, '2 Trebol3': 2, '3 Trebol3': 3, "4 Trebol3": 4, 
           '5 Trebol3': 5,'6 Trebol3': 6, '7 Trebol3': 7, '8 Trebol3': 8, '9 Trebol3': 9, '10 Trebol3': 10, 'Joto Trebol3': 10,
           'Quina Trebol3': 10, 'Rey Trebol3': 10}

cartas4 = {'As corazon4': 1, '2 corazon4': 2, '3 corazon4': 3, "4 corazon4": 4, '5 corazon4': 5, '6 corazon4': 6, 
           '7 corazon4': 7, '8 corazon4': 8, '9 corazon4': 9, '10 corazon4': 10, 'Joto corazo4': 10, 'Quina Corazon4': 10, 
           'Rey Corazon4': 10, 'As Diamante4': 1, "2 Diamante4": 2, "3 Diamante4": 3, "4 Diamante4": 4, "5 Diamante4": 5,
           '6 Diamante4': 6, '7 Diamante4': 7, '8 Diamante4': 8, '9 Diamante4': 9, '10 Diamante4': 10, 'Joto Diamante4': 10, 
           'Quina Diamante4': 10, 'Rey Diamante4': 10, 'As Espada4': 1, '2 Espada4': 2, '3 Espada4': 3, "4 Espada4": 4, 
           '5 Espada4': 5, '6 Espada4': 6, '7 Espada4': 7, '8 Espada4': 8, '9 Espada4': 9, '10 Espada4': 10, 'Joto Espada4': 10, 
           'Quina Espada4': 10, 'Rey Espada4': 10,'As Trebol4': 1, '2 Trebol4': 2, '3 Trebol4': 3, "4 Trebol4": 4, 
           '5 Trebol4': 5,'6 Trebol4': 6, '7 Trebol4': 7, '8 Trebol4': 8, '9 Trebol4': 9, '10 Trebol4': 10, 'Joto Trebol4': 10,
           'Quina Trebol4': 10, 'Rey Trebol4': 10}

cartas5 = {'As corazon5': 1, '2 corazon5': 2, '3 corazon5': 3, "4 corazon5": 4, '5 corazon5': 5, '6 corazon5': 6, 
           '7 corazon5': 7, '8 corazon5': 8, '9 corazon5': 9, '10 corazon5': 10, 'Joto corazo5': 10, 'Quina Corazon5': 10, 
           'Rey Corazon5': 10, 'As Diamante5': 1, "2 Diamante5": 2, "3 Diamante5": 3, "4 Diamante5": 4, "5 Diamante5": 5,
           '6 Diamante5': 6, '7 Diamante5': 7, '8 Diamante5': 8, '9 Diamante5': 9, '10 Diamante5': 10, 'Joto Diamante5': 10, 
           'Quina Diamante5': 10, 'Rey Diamante5': 10, 'As Espada5': 1, '2 Espada5': 2, '3 Espada5': 3, "4 Espada5": 4, 
           '5 Espada5': 5, '6 Espada5': 6, '7 Espada5': 7, '8 Espada5': 8, '9 Espada5': 9, '10 Espada5': 10, 'Joto Espada5': 10, 
           'Quina Espada5': 10, 'Rey Espada5': 10,'As Trebol5': 1, '2 Trebol5': 2, '3 Trebol5': 3, "4 Trebol5": 4, 
           '5 Trebol5': 5,'6 Trebol5': 6, '7 Trebol5': 7, '8 Trebol5': 8, '9 Trebol5': 9, '10 Trebol5': 10, 'Joto Trebol5': 10,
           'Quina Trebol5': 10, 'Rey Trebol5': 10}

##########################################################################################################################    
#dinero_usuario = 100
#jugar=0
#while (jugar != '2' and dinero_usuario >=10):
    #print("Si quieres jugar presiona: 1")
    #print("Si no quieres jugar presiona: 2")
    #print("Tienes  $",dinero_usario," para apostar, cada mano ganas o pierdes $10")
    #print("\n")
    #jugar = (input())
    #while (jugar != '1' and jugar != '2'):
        #print("Entrega una opcion correcta 1 o 2")
        #jugar = (input())
        
    #if jugar == '1':

#------------------------------------------------------------------------------------
deck= random.randint(1,5)
manousuario={}
manocasino={}
for i in range(4):
    if i == 0 or i == 2:
        if deck == 1:
            cartas_list=list(cartas1.keys())
            cartas_random=random.randint(0,51)
            x = key_cartas=cartas_list[cartas_random]
            y = value_cartas=cartas1.get(cartas_list[cartas_random])
            #del cartas1[x]

        elif deck == 2:
            cartas_list=list(cartas2.keys())
            cartas_random=random.randint(0,51)
            x = key_cartas=cartas_list[cartas_random]
            y = value_cartas=cartas2.get(cartas_list[cartas_random])
            #del cartas2[x]
       
        elif deck == 3:
            cartas_list=list(cartas3.keys())
            cartas_random=random.randint(0,51)
            x = key_cartas=cartas_list[cartas_random]
            y = value_cartas=cartas3.get(cartas_list[cartas_random])
            #del cartas3[x]

        elif deck == 4:
            cartas_list=list(cartas4.keys())
            cartas_random=random.randint(0,51)
            x = key_cartas=cartas_list[cartas_random]
            y = value_cartas=cartas4.get(cartas_list[cartas_random])
            #del cartas4[x]

        elif deck == 5:
            cartas_list=list(cartas5.keys())
            cartas_random=random.randint(0,51)
            x = key_cartas=cartas_list[cartas_random]
            y = value_cartas=cartas5.get(cartas_list[cartas_random])
            #del cartas5[x]
        
        manousuario[x] = y


    else:
        
        if deck == 1:
            cartas_list=list(cartas1.keys())
            cartas_random=random.randint(0,51)
            x = key_cartas=cartas_list[cartas_random]
            y = value_cartas=cartas1.get(cartas_list[cartas_random])
            #del cartas1[x]

        elif deck == 2:
            cartas_list=list(cartas2.keys())
            cartas_random=random.randint(0,51)
            x = key_cartas=cartas_list[cartas_random]
            y = value_cartas=cartas2.get(cartas_list[cartas_random])
            #del cartas2[x]
       
        elif deck == 3:
            cartas_list=list(cartas3.keys())
            cartas_random=random.randint(0,51)
            x = key_cartas=cartas_list[cartas_random]
            y = value_cartas=cartas3.get(cartas_list[cartas_random])
            #del cartas3[x]

        elif deck == 4:
            cartas_list=list(cartas4.keys())
            cartas_random=random.randint(0,51)
            x = key_cartas=cartas_list[cartas_random]
            y = value_cartas=cartas4.get(cartas_list[cartas_random])
            #del cartas4[x]

        elif deck == 5:
            cartas_list=list(cartas5.keys())
            cartas_random=random.randint(0,51)
            x = key_cartas=cartas_list[cartas_random]
            y = value_cartas=cartas5.get(cartas_list[cartas_random])
            #del cartas5[x]
        
        manocasino[x] = y
        
valores_casino = list(manocasino.values()) 
keys_casino = list(manocasino.keys())
contador = 0
suma_casino = sum(manocasino.values())
for j in valores_casino:
    if j == 1 and suma_casino < 12:
        manocasino[keys_casino[contador]] = 11
        suma_casino = sum (manocasino.values())
    elif j == 1:
        manocasino[keys_casino[contador]] = valores_casino[contador]
    contador = contador + 1
    

valores_usuario = list(manousuario.values()) 
keys_usuario = list(manousuario.keys())
contador = 0
suma_usuario = sum(manousuario.values())
for k in valores_usuario:
    if k == 1 and suma_usuario < 12:
        manousuario[keys_usuario[contador]] = 11
        suma_usuario = sum (manousuario.values())
    elif k == 1:
        manousuario[keys_usuario[contador]] = valores_usuario[contador]
    contador = contador + 1
        



suma_usuario = sum (manousuario.values())
suma_casino = sum (manocasino.values())
print("Puntos Inciales")
print("Usuario:",manousuario,"  Puntos Usuario:",suma_usuario)
print("Casino:", manocasino,"  Puntos Casino:",suma_casino)
print("\n")



########################################################################################################

print("Si quieres otra carta presiona: 1")
print("Si quieres parar presiona: 2")
print("\n")
inp_usu = 1
while (inp_usu != '2' and suma_usuario <= 21):
    inp_usu =(input())
    if inp_usu != '2' and inp_usu != '1':
        print("Numero erroneo selecciona 1 o 2")
    if inp_usu == '1':
        deck= random.randint(1,5)
        if deck == 1:
            cartas_list=list(cartas1.keys())
            cartas_random=random.randint(0,51)
            x = key_cartas=cartas_list[cartas_random]
            y = value_cartas=cartas1.get(cartas_list[cartas_random])
            #del cartas1[x]

        elif deck == 2:
            cartas_list=list(cartas2.keys())
            cartas_random=random.randint(0,51)
            x = key_cartas=cartas_list[cartas_random]
            y = value_cartas=cartas2.get(cartas_list[cartas_random])
            #del cartas2[x]
       
        elif deck == 3:
            cartas_list=list(cartas3.keys())
            cartas_random=random.randint(0,51)
            x = key_cartas=cartas_list[cartas_random]
            y = value_cartas=cartas3.get(cartas_list[cartas_random])
            #del cartas3[x]

        elif deck == 4:
            cartas_list=list(cartas4.keys())
            cartas_random=random.randint(0,51)
            x = key_cartas=cartas_list[cartas_random]
            y = value_cartas=cartas4.get(cartas_list[cartas_random])
            #del cartas4[x]

        elif deck == 5:
            cartas_list=list(cartas5.keys())
            cartas_random=random.randint(0,51)
            x = key_cartas=cartas_list[cartas_random]
            y = value_cartas=cartas5.get(cartas_list[cartas_random])
            #del cartas5[x]
            
        manousuario[x] = y
#################################################################################################################33           
        valores_usuario = list(manousuario.values())
        keys_usuario = list(manousuario.keys())
        contador = 0
        suma_usuario = sum(manousuario.values())
        for i in valores_usuario:
    
            if i == 1  and suma_usuario < 12:
                manousuario[keys_usuario[contador]] = 11
                suma_usuario = sum (manousuario.values())
        
            elif i == 11 and suma_usuario < 12:
                manousuario[keys_usuario[contador]] = 11
                suma_usuario = sum (manousuario.values())
        
            elif i == 1 and suma_usuario >= 12:
                manousuario[keys_usuario[contador]] = 1
                suma_usuario = sum (manousuario.values())
    
            elif i == 11 and suma_usuario > 21:
                manousuario[keys_usuario[contador]] = 1
                suma_usuario = sum (manousuario.values())
            contador = contador + 1
            suma_usuario = sum(manousuario.values())
            valores_usuario = list(manousuario.values())
    
###########################################################################################################3333333        
        suma_usuario = sum (manousuario.values())
        
    print("Usuario:",manousuario,"  Suma:",suma_usuario)
    print("\n")
#print("\n")

#if suma_usuario > 21:
    #print("Perdiste te pasaste de 21")
x="" 

###################################################################################################################

if suma_usuario <= 21 and suma_casino < 21:
    while (suma_casino < 17):
        deck= random.randint(1,5)
        if deck == 1:
            cartas_list=list(cartas1.keys())
            cartas_random=random.randint(0,51)
            x = key_cartas=cartas_list[cartas_random]
            y = value_cartas=cartas1.get(cartas_list[cartas_random])
            #del cartas1[x]

        elif deck == 2:
            cartas_list=list(cartas2.keys())
            cartas_random=random.randint(0,51)
            x = key_cartas=cartas_list[cartas_random]
            y = value_cartas=cartas2.get(cartas_list[cartas_random])
            #del cartas2[x]
       
        elif deck == 3:
            cartas_list=list(cartas3.keys())
            cartas_random=random.randint(0,51)
            x = key_cartas=cartas_list[cartas_random]
            y = value_cartas=cartas3.get(cartas_list[cartas_random])
            #del cartas3[x]

        elif deck == 4:
            cartas_list=list(cartas4.keys())
            cartas_random=random.randint(0,51)
            x = key_cartas=cartas_list[cartas_random]
            y = value_cartas=cartas4.get(cartas_list[cartas_random])
            #del cartas4[x]

        elif deck == 5:
            cartas_list=list(cartas5.keys())
            cartas_random=random.randint(0,51)
            x = key_cartas=cartas_list[cartas_random]
            y = value_cartas=cartas5.get(cartas_list[cartas_random])
            #del cartas5[x]
                   
        manocasino[x] = y
################################################################################################################333        
        valores_casino = list(manocasino.values())
        keys_casino = list(manocasino.keys())
        contador = 0
        suma_casino = sum(manocasino.values())
        for i in valores_casino:
    
            if i == 1  and suma_casino < 12:
                manocasino[keys_casino[contador]] = 11
                suma_casino = sum (manocasino.values())
        
            elif i == 11 and suma_casino < 12:
                manocasino[keys_casino[contador]] = 11
                suma_casino = sum (manocasino.values())
        
            elif i == 1 and suma_casino >= 12:
                manocasino[keys_casino[contador]] = 1
                suma_casino = sum (manocasino.values())
    
            elif i == 11 and suma_casino > 21:
                manocasino[keys_casino[contador]] = 1
            contador = contador + 1
            suma_casino = sum(manocasino.values())
            valores_casino = list(manocasino.values())
    
#############################################################################################################333333            
        suma_casino = sum (manocasino.values())
    
    print("Casino:",manocasino,"  Suma:",suma_casino)
    print("Usuario:",manousuario,"  Suma:",suma_usuario)
    
    if suma_casino > suma_usuario and suma_casino <= 21:
        print("Gana el Casino")
    elif suma_casino == suma_usuario:
        print("Empate")
    else:
        print("Gana Usuario")
    
else:
    print("Casino:",manocasino,"  Suma:",suma_casino)
    print("Usuario:",manousuario,"  Suma:",suma_usuario)
    print("Gana el Casino")
# Out:
# Puntos Inciales
# Usuario: {'As corazon4': 11, '5 Diamante4': 5}   Puntos Usuario: 16
# Casino: {'4 corazon4': 4, 'Rey Corazon4': 10}   Puntos Casino: 14
#
#
# Si quieres otra carta presiona: 1
# Si quieres parar presiona: 2
#
#
# 1
# Usuario: {'As corazon4': 1, '5 Diamante4': 5, '7 Diamante2': 7}   Suma: 13
